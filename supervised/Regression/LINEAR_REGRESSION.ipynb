# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.random.randint(0,101,(4,3))
data
# Out:
# array([[22, 75, 44],
#        [24, 46, 52],
#        [55, 95, 31],
#        [43, 90, 21]])

# %%
df = pd.DataFrame(data)
df
# Out:
#     0   1   2
# 0  22  75  44
# 1  24  46  52
# 2  55  95  31
# 3  43  90  21

# %%
dataa = pd.read_csv('/content/sample_data/california_housing_test.csv')
dataa.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
dff = dataa.iloc[0]

# %%
dff = dataa.iloc[0]
dataa.drop(dataa.index[-1],axis = 0,inplace = True)
dataa
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2994       516.0       174.0         5.5867            182500.0
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
#
# [2999 rows x 9 columns]

# %%
dataa[(dataa['total_rooms'] > 5000) & (dataa['latitude'] > 30)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19      -122.59     38.01                35.0       8814.0          1307.0
# 24      -117.28     33.28                13.0       6131.0          1040.0
# 33      -118.08     34.55                 5.0      16181.0          2971.0
# 39      -119.01     34.23                11.0       5785.0          1035.0
# 45      -117.24     33.17                 4.0       9998.0          1874.0
# ...         ...       ...                 ...          ...             ...
# 2936    -119.75     36.87                 3.0      13802.0          2244.0
# 2968    -119.23     34.17                18.0       6171.0          1490.0
# 2969    -118.11     34.68                 6.0       7430.0          1184.0
# 2971    -120.93     35.76                11.0       8997.0          1698.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# 19        3450.0      1258.0         6.1724            414300.0
# 24        4049.0       940.0         3.8156            150700.0
# 33        8152.0      2651.0         4.5237            141800.0
# 39        2760.0       985.0         4.6930            232200.0
# 45        3925.0      1672.0         4.2826            237500.0
# ...          ...         ...            ...                 ...
# 2936      5226.0      1972.0         5.0941            143700.0
# 2968      2164.0      1210.0         3.6875            500001.0
# 2969      3489.0      1115.0         5.3267            140100.0
# 2971      1825.0       756.0         3.2300            154300.0
# 2996      3496.0      1036.0         3.3906            237200.0
#
# [248 rows x 9 columns]

# %%
def lasttwodigits (perm):
  return (str(perm)[-2:])

# %%
dataa['households'].apply(lasttwodigits)
# Out:
# 0       .0
# 1       .0
# 2       .0
# 3       .0
# 4       .0
#         ..
# 2994    .0
# 2995    .0
# 2996    .0
# 2997    .0
# 2998    .0
# Name: households, Length: 2999, dtype: object

# %%
# data2 = np.vectorize(lasttwodigits)(dataa['households'],dataa['latitude'])

# %%
dataa.sort_values('population')
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2640    -114.62     33.62                26.0         18.0             3.0
# 740     -117.12     32.66                52.0         16.0             4.0
# 1115    -116.95     33.86                 1.0          6.0             2.0
# 2494    -118.44     34.04                49.0         32.0             7.0
# 1355    -117.11     32.66                52.0         25.0             5.0
# ...         ...       ...                 ...          ...             ...
# 1597    -117.12     33.49                 4.0      21988.0          4055.0
# 2429    -117.20     33.58                 2.0      30450.0          5033.0
# 1146    -117.27     33.15                 4.0      23915.0          4135.0
# 2186    -116.14     34.45                12.0       8796.0          1721.0
# 978     -121.53     38.48                 5.0      27870.0          5027.0
#
#       population  households  median_income  median_house_value
# 2640         5.0         3.0         0.5360            275000.0
# 740          8.0         3.0         1.1250             60000.0
# 1115         8.0         2.0         1.6250             55000.0
# 2494        14.0         7.0         2.1875            225000.0
# 1355        14.0         9.0         1.6250            118800.0
# ...          ...         ...            ...                 ...
# 1597      8824.0      3252.0         3.9963            191100.0
# 2429      9419.0      3197.0         4.5936            174300.0
# 1146     10877.0      3958.0         4.6357            244900.0
# 2186     11139.0      1680.0         2.2612            137500.0
# 978      11935.0      4855.0         4.8811            212200.0
#
# [2999 rows x 9 columns]

# %%
dataa.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925071           -0.064208     0.049864
# latitude            -0.925071  1.000000           -0.024950    -0.039709
# housing_median_age  -0.064208 -0.024950            1.000000    -0.367791
# total_rooms          0.049864 -0.039709           -0.367791     1.000000
# total_bedrooms       0.070870 -0.068376           -0.323011     0.937754
# population           0.111575 -0.117452           -0.299743     0.838862
# households           0.051061 -0.068424           -0.305027     0.914118
# median_income       -0.018704 -0.071957           -0.145397     0.221828
# median_house_value  -0.050702 -0.138096            0.090619     0.160948
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.070870    0.111575    0.051061      -0.018704
# latitude                 -0.068376   -0.117452   -0.068424      -0.071957
# housing_median_age       -0.323011   -0.299743   -0.305027      -0.145397
# total_rooms               0.937754    0.838862    0.914118       0.221828
# total_bedrooms            1.000000    0.856368    0.970754       0.024603
# population                0.856368    1.000000    0.895516       0.032938
# households                0.970754    0.895516    1.000000       0.049220
# median_income             0.024603    0.032938    0.049220       1.000000
# median_house_value        0.082936   -0.000646    0.100843       0.671966
#
#                     median_house_value
# longitude                    -0.050702
# latitude                     -0.138096
# housing_median_age            0.090619
# total_rooms                   0.160948
# total_bedrooms                0.082936
# population                   -0.000646
# households                    0.100843
# median_income                 0.671966
# median_house_value            1.000000

# %%
dataa['population'].idxmax()
# Out:
# 978

# %%
dataa.iloc[978]
# Out:
# longitude               -121.5300
# latitude                  38.4800
# housing_median_age         5.0000
# total_rooms            27870.0000
# total_bedrooms          5027.0000
# population             11935.0000
# households              4855.0000
# median_income              4.8811
# median_house_value    212200.0000
# Name: 978, dtype: float64

# %%
dataa.groupby('median_house_value').mean().transpose()
# Out:
# median_house_value   22500.0   37500.0    39200.0    39800.0    40000.0   \
# longitude           -117.1600 -123.0800  -119.9700  -117.6500  -122.0600
# latitude              32.7100   40.4000    36.4400    35.0000    37.3900
# housing_median_age    52.0000   10.0000    18.0000    36.0000    22.0000
# total_rooms          845.0000  365.0000  1128.0000  1184.0000  1236.0000
# total_bedrooms       451.0000  102.0000   237.0000   316.0000   290.0000
# population          1230.0000  140.0000   772.0000   672.0000   413.0000
# households           375.0000   49.0000   220.0000   241.0000   274.0000
# median_income          1.0918    1.7969     2.1771     1.9107     3.6875
#
# median_house_value   41500.0   42500.0   42700.0    43100.0    43300.0   ...  \
# longitude           -119.1400 -121.5700  -119.460  -119.0200  -119.7800  ...
# latitude              36.0600   39.4800    35.860    36.0600    36.7300  ...
# housing_median_age    32.0000   15.0000    22.000    41.0000    52.0000  ...
# total_rooms         1838.0000  202.0000  1750.000  2279.0000  1377.0000  ...
# total_bedrooms       441.0000   54.0000   374.000   538.0000   319.0000  ...
# population          1628.0000  145.0000  1113.000  1908.0000  1280.0000  ...
# households           425.0000   40.0000   338.000   511.0000   259.0000  ...
# median_income          1.6452    0.8252     1.505     1.3952     1.2344  ...
#
# median_house_value   487100.0   489800.0   492000.0   492300.0   493200.0  \
# longitude           -121.9400  -118.4300  -122.1600  -122.4400  -118.1300
# latitude              36.5500    34.0100    37.4500    37.7800    34.1300
# housing_median_age    30.0000    43.0000    52.0000    37.0000    39.0000
# total_rooms         2722.0000  1487.0000  1135.0000  1235.0000  2099.0000
# total_bedrooms       584.0000   242.0000   219.0000   314.0000   397.0000
# population           628.0000   675.0000   441.0000   481.0000  1500.0000
# households           384.0000   247.0000   200.0000   297.0000   380.0000
# median_income          3.4048     5.3403     7.5418     3.6875     4.8304
#
# median_house_value   494700.0   495500.0   495800.0   500000.0     500001.0
# longitude           -118.4300  -118.3900  -122.7100  -121.2950  -119.654355
# latitude              34.0400    33.8800    37.8800    36.5025    35.157903
# housing_median_age    52.0000    33.0000    21.0000    39.7500    32.862903
# total_rooms         2425.0000  2543.0000  2845.0000  2918.7500  3224.016129
# total_bedrooms       435.0000   439.0000   552.0000   515.2500   568.669355
# population           962.0000  1098.0000   599.0000  1030.0000  1210.612903
# households           412.0000   416.0000   250.0000   483.0000   522.508065
# median_income          5.8587     5.9683     4.3125     5.2311     7.697089
#
# [8 rows x 1784 columns]

# %%
dataa['total'] = dataa['latitude'] + dataa['longitude']
dataa
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
#
#       population  households  median_income  median_house_value  total
# 0         1537.0       606.0         6.6085            344700.0 -84.68
# 1          809.0       277.0         3.5990            176500.0 -84.04
# 2         1484.0       495.0         5.7934            270500.0 -84.03
# 3           49.0        11.0         6.1359            330000.0 -84.54
# 4          850.0       237.0         2.9375             81700.0 -83.34
# ...          ...         ...            ...                 ...    ...
# 2994       516.0       174.0         5.5867            182500.0 -84.07
# 2995      1258.0       607.0         1.1790            225000.0 -85.44
# 2996      3496.0      1036.0         3.3906            237200.0 -84.08
# 2997       693.0       220.0         2.2895             62000.0 -83.40
# 2998        46.0        14.0         3.2708            162500.0 -83.02
#
# [2999 rows x 10 columns]

# %%
X = dataa['total_bedrooms']
y = dataa['median_house_value']
np.polyfit(X,y,deg = 1)
# Out:
# array([2.25468672e+01, 1.93797456e+05])

# %%
potential_spend = np.linspace(100,5000,500)
predected_val = 2.25468672e+01*potential_spend +  1.93797456e+05
plt.plot(potential_spend,predected_val)

# %%
dataa.drop('total',axis = 1)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2994       516.0       174.0         5.5867            182500.0
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
#
# [2999 rows x 9 columns]

# %%
X = dataa.iloc[:, 0:-3]
y = dataa.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size= 0.30,random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Confusion matrics is used for classification task and R squared is used for Regression task so we use R squared here

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# making liner relation into polynomial to better understadn the relaiton bteween the variable

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_converter = PolynomialFeatures(degree = 2, include_bias= True)

# %%
poly_feature = poly_converter.fit_transform(X)
X_train,X_test,y_train,y_test = train_test_split(poly_feature,y,test_size= 0.30,random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# Confusion matrics is used for classification task and R squared is used for Regression task so we use R squared here

# %% [markdown]
# Calculating error

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
MAE = mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
RMSE = np.sqrt(MSE)
print(MAE,MSE,RMSE)
# Out:
# 2.4110881548090726e-09 1.5780920487207005e-17 3.972520671715505e-09

# %% [markdown]
# Testing which degree of polynomial fits best in our model

# %%
# for i in range(1,10):
#   poly_converter = PolynomialFeatures(degree = i, include_bias= False)
#   poly_feature =  poly_converter.fit_transform(X)
#   X_train,X_test,y_train,y_test = train_test_split(poly_feature,y,test_size= 0.30,random_state = 42)
#   model = LinearRegression()
#   model.fit(X_train,y_train)
#   y_pred_train = model.predict(X_train)
#   y_pred_test = model.predict(X_test)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
dataa.corr()['median_house_value']
# Out:
# longitude            -0.050702
# latitude             -0.138096
# housing_median_age    0.090619
# total_rooms           0.160948
# total_bedrooms        0.082936
# population           -0.000646
# households            0.100843
# median_income         0.671966
# median_house_value    1.000000
# total                -0.488434
# Name: median_house_value, dtype: float64

# %%
plt.scatter(dataa['median_house_value'],dataa['median_income'])
